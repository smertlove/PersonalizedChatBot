# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from src import ChatBot

# %%
chatbot = ChatBot(use_vllm=True)

# %%
print(chatbot.response("""
I am 32. I do not want a job. I play video games all day. I still live at home with my parents. My favorite drink is iced coffee. I have a black belt in karate. I m in a jazz band and play the saxophone. I vacation along lake michigan every summer.
"""))
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 116.58it/s]
# That’s great to hear you’re enjoying your summer vacation at Lake Michigan and continuing to pursue your passions! It’s wonderful that you’re balancing your love of video games, jazz, and karate with a relaxed lifestyle at home.

# %%
print(chatbot.response("I really want to play Genshin Impact all night, but I'm afraid my parents will punish me."))
# Out:
# It’s understandable to want to unwind and enjoy your favorite games, but it’s good to be mindful of your parents’ expectations. Perhaps you could discuss with them about setting boundaries for gaming time, ensuring you’re still respecting their rules while still pursuing your interests?

# %%
print(chatbot.response("Am I an anime fan?"))
# Out:
# As a jazz musician, you certainly have a creative and expressive side – it’s interesting to think about how that might intersect with your interest in anime!

# %%
print(chatbot.response("How old am I?"))
# Out:
# You’re 32 years old!

# %%
print(chatbot.response("I am 25."))
# Out:
# That’s interesting – it seems like you’re experiencing a bit of a shift in your life! It’s great you’re exploring new things and finding outlets for your passions.

# %%
print(chatbot.response("How old am I?"))
# Out:
# You’re 25 years old!
